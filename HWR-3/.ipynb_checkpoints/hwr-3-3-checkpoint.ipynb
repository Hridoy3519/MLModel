# %% [markdown]
# ## Data collection

# %%
# import tarfile
# from tqdm import tqdm
# from urllib.request import urlopen
# from io import BytesIO
# from zipfile import ZipFile
# import os

# def download_and_unzip(url, extract_to='Datasets', chunk_size=1024*1024):
#     http_response = urlopen(url)

#     data = b''
#     iterations = http_response.length // chunk_size + 1
#     for _ in tqdm(range(iterations)):
#         data += http_response.read(chunk_size)

#     zipfile = ZipFile(BytesIO(data))
#     zipfile.extractall(path=extract_to)

# dataset_path = os.path.join('Datasets', 'IAM_Words')
# if not os.path.exists(dataset_path):
#     download_and_unzip('https://git.io/J0fjL', extract_to='Datasets')

#     file = tarfile.open(os.path.join(dataset_path, "words.tgz"))
#     file.extractall(os.path.join(dataset_path, "words"))

# %% [markdown]
# ## Imports

# %%
import matplotlib.pyplot as plt
from datetime import datetime
import tensorflow as tf
import numpy as np
import os

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers.experimental.preprocessing import StringLookup
from tensorflow import keras

np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Dataset Preprocessing

# %%
base_path = "Datasets\IAM_Words"
words_list = []

words = open(f"{base_path}/words.txt", "r").readlines()
for line in words:
    if line[0] == "#":
        continue
    if line.split(" ")[1] != "err":  # We don't need to deal with errored entries.
        words_list.append(line)

len(words_list)

np.random.shuffle(words_list)

# %% [markdown]
# ### Spliting
# 90% training , 5% validation and 5% for testing

# %%
train_samples, test_samples = train_test_split(words_list, test_size=0.1, random_state=42)
validation_samples, test_samples = train_test_split(test_samples, test_size=0.5, random_state=42)

# Number of samples in each set
print(f"Total training samples: {len(train_samples)}")
print(f"Total validation samples: {len(validation_samples)}")
print(f"Total test samples: {len(test_samples)}")
# Out:
# Total training samples: 86810
# Total validation samples: 4823
# Total test samples: 4823

# %%
for i in train_samples[:5]:
    print(i)
# Out:
# n02-120-03-02 ok 182 929 1313 37 25 AT a
#
# g06-026k-02-02 ok 182 884 1102 121 44 RB ever
#
# e07-061-08-07 ok 157 1856 2179 147 66 HVD had
#
# e04-019-01-07 ok 173 1939 920 223 104 NN choice
#
# g06-105-03-04 ok 188 1263 1313 122 48 JJB main

# %% [markdown]
# ### Getting Image path & Clean label
#
# e04-019-01-07 ok 173 1939 920 223 104 NN choice
#
# Here destination folder is words/e04/e04-019/e04-019-01-07.png -> choice
#
# choice is the label

# %%
base_image_path = os.path.join(base_path, "words")

def get_image_paths_and_labels(samples):
    paths = []
    labels = []
    for (i, file_line) in enumerate(samples):
        line_split = file_line.strip()
        line_split = line_split.split(" ")

        image_name = line_split[0]
        folder_1 = image_name.split("-")[0]
        folder_2 = image_name.split("-")[1]
        img_path = os.path.join(
            base_image_path, folder_1, folder_1 + "-" + folder_2, image_name + ".png"
        )
        if os.path.getsize(img_path):
            paths.append(img_path)
            labels.append(line_split[-1])

    return paths, labels


train_img_paths, train_labels = get_image_paths_and_labels(train_samples)
validation_img_paths, validation_labels = get_image_paths_and_labels(validation_samples)
test_img_paths, test_labels = get_image_paths_and_labels(test_samples)

# %%
train_labels[:10]
# Out:
# ['a',
#  'ever',
#  'had',
#  'choice',
#  'main',
#  'sea-farers',
#  'a',
#  'animals',
#  'his',
#  'image']

# %% [markdown]
# ### Finding max Char in a label and the size of the vocabulary in the training data.

# %%
characters = set()
max_len = 0

for label in train_labels:
    for char in label:
        characters.add(char)
    max_len = max(max_len, len(label))

characters = sorted(list(characters))
train_labels_cleaned = train_labels
print("Maximum length: ", max_len)
print("Vocabulary size: ", len(characters))
# Out:
# Maximum length:  21
# Vocabulary size:  78

# %% [markdown]
# ### Building the character vocabulary
# Our study involves preprocessing labels at the character level.
#
# This means that if there are 3 labels "who", "are" and "how" then our character
# vocabulary should be {a, e, h, o, r, w}.
#
# We are using the [`StringLookup`](https://keras.io/api/layers/preprocessing_layers/categorical/string_lookup/) layer for this purpose.

# %%
AUTOTUNE = tf.data.AUTOTUNE

# Mapping characters to integers.
char_to_num = StringLookup(vocabulary=list(characters), mask_token=None)

# Mapping integers back to original characters.
num_to_char = StringLookup(
    vocabulary=char_to_num.get_vocabulary(), mask_token=None, invert=True
)

# %% [markdown]
# ### Images Resizing
#
# Instead of square images, many OCR models work with rectangular images. Here we using rectangular images too.
# Because in this case most of the time our words will be in rectangular shape rather then squre.
#
# If we use squre then this will add more padding to our images
#
# By using rectangular image we preserved the aspect ratio and content of the images is not affected too.

# %%
def distortion_free_resize(image, img_size):
    w, h = img_size
    image = tf.image.resize(image, size=(h, w), preserve_aspect_ratio=True)

    # Checking tha amount of padding needed to be done.
    pad_height = h - tf.shape(image)[0]
    pad_width = w - tf.shape(image)[1]

    # giving same amount of padding on both sides.
    if pad_height % 2 != 0:
        height = pad_height // 2
        pad_height_top = height + 1
        pad_height_bottom = height
    else:
        pad_height_top = pad_height_bottom = pad_height // 2

    if pad_width % 2 != 0:
        width = pad_width // 2
        pad_width_left = width + 1
        pad_width_right = width
    else:
        pad_width_left = pad_width_right = pad_width // 2

    image = tf.pad(
        image,
        paddings=[
            [pad_height_top, pad_height_bottom],
            [pad_width_left, pad_width_right],
            [0, 0],
        ],
    )

    image = tf.transpose(image, perm=[1, 0, 2])
    image = tf.image.flip_left_right(image)
    return image

# %% [markdown]
# ### All necessary functions to prepare our data into `tf.data.Dataset` objects

# %%
batch_size = 64
padding_token = 99
image_width = 128
image_height = 32


def preprocess_image(image_path, img_size=(image_width, image_height)):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, 1)
    image = distortion_free_resize(image, img_size)
    image = tf.cast(image, tf.float32) / 255.0
    return image


def vectorize_label(label):
    label = char_to_num(tf.strings.unicode_split(label, input_encoding="UTF-8"))
    length = tf.shape(label)[0]
    pad_amount = max_len - length
    label = tf.pad(label, paddings=[[0, pad_amount]], constant_values=padding_token)
    return label


def process_images_labels(image_path, label):
    image = preprocess_image(image_path)
    label = vectorize_label(label)
    return {"image": image, "label": label}


def prepare_dataset(image_paths, labels):
    dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels)).map(
        process_images_labels, num_parallel_calls=AUTOTUNE
    )
    return dataset.batch(batch_size).cache().prefetch(AUTOTUNE)

# %%
# Converting into tf.data.Dataset object
train_ds = prepare_dataset(train_img_paths, train_labels)
validation_ds = prepare_dataset(validation_img_paths, validation_labels)
test_ds = prepare_dataset(test_img_paths, test_labels)

# %% [markdown]
# ### Getting real values from a tf.data.Dataset object.

# %%
def get_label_in_text (label):
    indices = tf.gather(label, tf.where(tf.math.not_equal(label, padding_token)))
    # Convert to string.
    label = tf.strings.reduce_join(num_to_char(indices))
    label = label.numpy().decode("utf-8")
    return label

# %% [markdown]
# ### Visualizing a few samples

# %%
for data in train_ds.take(1):
    images, labels = data["image"], data["label"]

    _, ax = plt.subplots(5, 5, figsize=(15, 8))

    for i in range(25):
        img = images[i]
        img = tf.image.flip_left_right(img)
        img = tf.transpose(img, perm=[1, 0, 2])
        img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
        img = img[:, :, 0]

        # Gather indices where label!= padding_token.
        label = labels[i]
        indices = tf.gather(label, tf.where(tf.math.not_equal(label, padding_token)))
        # Convert to string.
        label = tf.strings.reduce_join(num_to_char(indices))
        label = label.numpy().decode("utf-8")

        ax[i // 5, i % 5].imshow(img, cmap="gray")
        ax[i // 5, i % 5].set_title(label)
        ax[i // 5, i % 5].axis("off")


plt.show()

# %% [markdown]
# ## Model Build
#
# Our model will use the CTC loss as an endpoint layer.

# %%
class CTCLayer(keras.layers.Layer):
    def __init__(self, name=None, **kwargs):
        super(CTCLayer, self).__init__(name=name, **kwargs)
        self.loss_fn = keras.backend.ctc_batch_cost

    def call(self, y_true, y_pred):
        batch_len = tf.cast(tf.shape(y_true)[0], dtype="int64")
        input_length = tf.cast(tf.shape(y_pred)[1], dtype="int64")
        label_length = tf.cast(tf.shape(y_true)[1], dtype="int64")

        input_length = input_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        label_length = label_length * tf.ones(shape=(batch_len, 1), dtype="int64")
        loss = self.loss_fn(y_true, y_pred, input_length, label_length)
        self.add_loss(loss)

        # For test time, just returning the computed predictions.
        return y_pred

    def get_config(self):
        config = super(CTCLayer, self).get_config()
        return config


def build_model():
    # Inputs to the model
    input_img = keras.Input(shape=(image_width, image_height, 1), name="image")
    labels = keras.layers.Input(name="label", shape=(None,))

    # First conv block.
    x = keras.layers.Conv2D(
        32,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv1",
    )(input_img)
    x = keras.layers.MaxPooling2D((2, 2), name="pool1")(x)

    # Second conv block.
    x = keras.layers.Conv2D(
        64,
        (3, 3),
        activation="relu",
        kernel_initializer="he_normal",
        padding="same",
        name="Conv2",
    )(x)
    x = keras.layers.MaxPooling2D((2, 2), name="pool2")(x)

    # We have used two max pool with pool size and strides 2. 
    # Hence, downsampled feature maps are 4x smaller. The number of filters in the last layer is 64. 
    # Reshaping accordingly before passing the output to the RNN part of the model.

    new_shape = ((image_width // 4), (image_height // 4) * 64)
    x = keras.layers.Reshape(target_shape=new_shape, name="reshape")(x)
    x = keras.layers.Dense(64, activation="relu", name="dense1")(x)
    x = keras.layers.Dropout(0.2)(x)

    # RNNs.
    x = keras.layers.Bidirectional(
        keras.layers.LSTM(128, return_sequences=True, dropout=0.25)
    )(x)
    x = keras.layers.Bidirectional(
        keras.layers.LSTM(64, return_sequences=True, dropout=0.25)
    )(x)

    # +2 is to account for the two special tokens introduced by the CTC loss.
    x = keras.layers.Dense(
        len(char_to_num.get_vocabulary()) + 2, activation="softmax", name="dense2"
    )(x)

    # Adding CTC layer for calculating CTC loss at each step.
    output = CTCLayer(name="ctc_loss")(labels, x)

    # Defining the model.
    model = keras.models.Model(
        inputs=[input_img, labels], outputs=output, name="handwriting_recognizer"
    )
    # Optimizer.
    opt = keras.optimizers.Adam()

    # Compiling the model and return.
    model.compile(optimizer=opt)
    return model


# Building the model.
model = build_model()
model.summary()
# Out:
# Model: "handwriting_recognizer"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image (InputLayer)             [(None, 128, 32, 1)  0           []
#                                 ]
#
#  Conv1 (Conv2D)                 (None, 128, 32, 32)  320         ['image[0][0]']
#
#  pool1 (MaxPooling2D)           (None, 64, 16, 32)   0           ['Conv1[0][0]']
#
#  Conv2 (Conv2D)                 (None, 64, 16, 64)   18496       ['pool1[0][0]']
#
#  pool2 (MaxPooling2D)           (None, 32, 8, 64)    0           ['Conv2[0][0]']
#
#  reshape (Reshape)              (None, 32, 512)      0           ['pool2[0][0]']
#
#  dense1 (Dense)                 (None, 32, 64)       32832       ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 32, 64)       0           ['dense1[0][0]']
#
#  bidirectional (Bidirectional)  (None, 32, 256)      197632      ['dropout[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 32, 128)     164352      ['bidirectional[0][0]']
#  )
#
#  label (InputLayer)             [(None, None)]       0           []
#
#  dense2 (Dense)                 (None, 32, 81)       10449       ['bidirectional_1[0][0]']
#
#  ctc_loss (CTCLayer)            (None, 32, 81)       0           ['label[0][0]',
#                                                                   'dense2[0][0]']
#
# ==================================================================================================
# Total params: 424,081
# Trainable params: 424,081
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Evaluation Metric -> Edit Distances.

# %% [markdown]
# We first segregate the validation images and their labels for convenience.

# %%
validation_images = []
validation_labels = []

for batch in validation_ds:
    validation_images.append(batch["image"])
    validation_labels.append(batch["label"])

# %% [markdown]
# Now, we create a callback to monitor the edit distances.

# %%
def calculate_edit_distance(labels, predictions):
    # Get a single batch and converting its labels to sparse tensors.
    saprse_labels = tf.cast(tf.sparse.from_dense(labels), dtype=tf.int64)

    # Making predictions and converting them to sparse tensors.
    input_len = np.ones(predictions.shape[0]) * predictions.shape[1]
    predictions_decoded = keras.backend.ctc_decode(
        predictions, input_length=input_len, greedy=True
    )[0][0][:, :max_len]
    sparse_predictions = tf.cast(
        tf.sparse.from_dense(predictions_decoded), dtype=tf.int64
    )

    # Computing individual edit distances and average them out.
    edit_distances = tf.edit_distance(
        sparse_predictions, saprse_labels, normalize=False
    )
    return tf.reduce_mean(edit_distances)

edit_distance_history = []

class EditDistanceCallback(keras.callbacks.Callback):
    def __init__(self, pred_model):
        super().__init__()
        self.prediction_model = pred_model

    def on_epoch_end(self, epoch, logs=None):
        edit_distances = []

        for i in range(len(validation_images)):
            labels = validation_labels[i]
            predictions = self.prediction_model.predict(validation_images[i])
            edit_distances.append(calculate_edit_distance(labels, predictions).numpy())

        edit_distance_history.append(np.mean(edit_distances))
        print(
            f"Mean edit distance for epoch {epoch + 1}: {np.mean(edit_distances):.4f}"
        )

# %% [markdown]
# ## Training
#
# Now we are ready to kick off model training.

# %%
epochs = 100

model = build_model()
prediction_model = keras.models.Model(
    model.get_layer(name="image").input, model.get_layer(name="dense2").output
)
edit_distance_callback = EditDistanceCallback(prediction_model)


#saving every model weights using Keras checkpoint
from keras.callbacks import ModelCheckpoint
# filepath="checkpoint/check-{epoch:02d}-{val_loss:.4f}.hdf5"
# checkpoint = ModelCheckpoint(filepath= filepath, verbose=1, save_best_only=False)


# Train the model.
history = model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    callbacks=[edit_distance_callback],
    # callbacks=[edit_distance_callback,checkpoint],
)

print(edit_distance_history)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 1s 29ms/steps - loss: 13.49
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 1s 1s/step
# Mean edit distance for epoch 1: 20.4504
# 1357/1357 [==============================] - 313s 225ms/step - loss: 13.4910 - val_loss: 11.7089
# Epoch 2/100
# 2/2 [==============================] - 0s 30ms/steps - loss: 10.49
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# Mean edit distance for epoch 2: 20.0620
# 1357/1357 [==============================] - 301s 222ms/step - loss: 10.4997 - val_loss: 9.4565
# Epoch 3/100
# 2/2 [==============================] - 0s 27ms/steps - loss: 8.73
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# Mean edit distance for epoch 3: 19.7437
# 1357/1357 [==============================] - 300s 221ms/step - loss: 8.7364 - val_loss: 7.6525
# Epoch 4/100
# 2/2 [==============================] - 0s 29ms/steps - loss: 6.99
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# Mean edit distance for epoch 4: 18.9101
# 1357/1357 [==============================] - 300s 221ms/step - loss: 6.9936 - val_loss: 5.6403
# Epoch 5/100
# 2/2 [==============================] - 0s 28ms/steps - loss: 5.61
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# Mean edit distance for epoch 5: 18.3994
# 1357/1357 [==============================] - 307s 226ms/step - loss: 5.6109 - val_loss: 4.5292
# Epoch 6/100
# 2/2 [==============================] - 0s 30ms/steps - loss: 4.73
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# Mean edit distance for epoch 6: 18.1021
# 1357/1357 [==============================] - 323s 238ms/step - loss: 4.7398 - val_loss: 3.8615
# Epoch 7/100
# 2/2 [==============================] - 0s 37ms/steps - loss: 4.18
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 35ms/step
# Mean edit distance for epoch 7: 17.9413
# 1357/1357 [==============================] - 307s 226ms/step - loss: 4.1845 - val_loss: 3.4237
# Epoch 8/100
# 2/2 [==============================] - 0s 26ms/steps - loss: 3.79
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# Mean edit distance for epoch 8: 17.8398
# 1357/1357 [==============================] - 308s 227ms/step - loss: 3.7990 - val_loss: 3.1417
# Epoch 9/100
# 2/2 [==============================] - 0s 29ms/steps - loss: 3.52
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# Mean edit distance for epoch 9: 17.8906
# 1357/1357 [==============================] - 307s 226ms/step - loss: 3.5259 - val_loss: 3.1078
# Epoch 10/100
# 2/2 [==============================] - 0s 28ms/steps - loss: 3.30
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 33ms/step
# Mean edit distance for epoch 10: 17.7757
# 1357/1357 [==============================] - 306s 226ms/step - loss: 3.3097 - val_loss: 2.8212
# Epoch 11/100
# 2/2 [==============================] - 0s 30ms/steps - loss: 3.14
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 33ms/step
# Mean edit distance for epoch 11: 17.6911
# 1357/1357 [==============================] - 306s 226ms/step - loss: 3.1400 - val_loss: 2.6757
# Epoch 12/100
# 2/2 [==============================] - 0s 29ms/steps - loss: 2.98
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# ...
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 163ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 162ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 138ms/step
# Mean edit distance for epoch 97: 17.2793
# 1357/1357 [==============================] - 976s 719ms/step - loss: 1.3082 - val_loss: 1.6672
# Epoch 98/100
# 2/2 [==============================] - 0s 182ms/step - loss: 1.
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 192ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 1/1 [==============================] - 0s 136ms/step
# Mean edit distance for epoch 98: 17.2799
# 1357/1357 [==============================] - 1064s 784ms/step - loss: 1.3073 - val_loss: 1.6475
# Epoch 99/100
# 2/2 [==============================] - 0s 170ms/step - loss: 1.
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 167ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 165ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 164ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 172ms/step
# 1/1 [==============================] - 0s 136ms/step
# Mean edit distance for epoch 99: 17.2627
# 1357/1357 [==============================] - 994s 733ms/step - loss: 1.3083 - val_loss: 1.6290
# Epoch 100/100
# 2/2 [==============================] - 0s 195ms/step - loss: 1.
# 2/2 [==============================] - 1s 347ms/step
# 2/2 [==============================] - 1s 378ms/step
# 2/2 [==============================] - 1s 291ms/step
# 2/2 [==============================] - 1s 295ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 1s 282ms/step
# 2/2 [==============================] - 1s 269ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 188ms/step
# 2/2 [==============================] - 0s 200ms/step
# 2/2 [==============================] - 0s 218ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 1s 294ms/step
# 2/2 [==============================] - 1s 342ms/step
# 2/2 [==============================] - 1s 410ms/step
# 2/2 [==============================] - 1s 397ms/step
# 2/2 [==============================] - 1s 289ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 194ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 1s 288ms/step
# 2/2 [==============================] - 1s 356ms/step
# 2/2 [==============================] - 1s 345ms/step
# 2/2 [==============================] - 1s 305ms/step
# 2/2 [==============================] - 1s 262ms/step
# 2/2 [==============================] - 1s 274ms/step
# 2/2 [==============================] - 1s 261ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 287ms/step
# 2/2 [==============================] - 1s 260ms/step
# 2/2 [==============================] - 1s 277ms/step
# 2/2 [==============================] - 1s 295ms/step
# 2/2 [==============================] - 1s 319ms/step
# 2/2 [==============================] - 1s 369ms/step
# 2/2 [==============================] - 1s 418ms/step
# 2/2 [==============================] - 1s 197ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 166ms/step
# Mean edit distance for epoch 100: 17.2832
# 1357/1357 [==============================] - 1194s 880ms/step - loss: 1.3046 - val_loss: 1.6790
# [20.431557, 20.367785, 20.015139, 20.450396, 20.062014, 19.743683, 18.9101, 18.39939, 18.102123, 17.941277, 17.83975, 17.89057, 17.7757, 17.691088, 17.676155, 17.585619, 17.621187, 17.550089, 17.564892, 17.572872, 17.501963, 17.576311, 17.521307, 17.488394, 17.441181, 17.478954, 17.480768, 17.427052, 17.411596, 17.426773, 17.446547, 17.42494, 17.389633, 17.403875, 17.433313, 17.366196, 17.37814, 17.38072, 17.372103, 17.40184, 17.374159, 17.370682, 17.345451, 17.352852, 17.34732, 17.34119, 17.354853, 17.349451, 17.368496, 17.331657, 17.351357, 17.335825, 17.321527, 17.319471, 17.33818, 17.339731, 17.289398, 17.308275, 17.335638, 17.317677, 17.331657, 17.320892, 17.316406, 17.29635, 17.304575, 17.307734, 17.307436, 17.31252, 17.312145, 17.304817, 17.315397, 17.327509, 17.310686, 17.287306, 17.315302, 17.312332, 17.304163, 17.30151, 17.294912, 17.29867, 17.291212, 17.292501, 17.294931, 17.300053, 17.293081, 17.289139, 17.291828, 17.320349, 17.28138, 17.299677, 17.313192, 17.29437, 17.295305, 17.301939, 17.29411, 17.280352, 17.28895, 17.284576, 17.300858, 17.279306, 17.279886, 17.262653, 17.283157]

# %%
print(history.history.keys())
# ploting history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# ### Saving model

# %%
current_date_time = datetime.now()
cdt_string = current_date_time.strftime("%d.%m.%y-%I.%M%p")

epoch = history.params['epochs']

loss = history.history['loss'][-1]
# zfill function add leading zeros so that the str is minimum 6 characters long. Ex: 06.300
loss = "{:.3f}".format(loss).zfill(6) 

model.save(f'Model/model-{epoch:03d}E-{loss}L-{cdt_string}.h5')

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Predicted float -> String / text function

# %%
# A utility function to decode the output
def decode_batch_predictions(pred):
    input_len = np.ones(pred.shape[0]) * pred.shape[1]

    results = keras.backend.ctc_decode(pred, input_length=input_len, greedy=True)[0][0][
        :, :max_len
    ]
    # Iterating over the results and getting the text.
    output_text = []
    for res in results:
        res = tf.gather(res, tf.where(tf.math.not_equal(res, -1)))
        res = tf.strings.reduce_join(num_to_char(res)).numpy().decode("utf-8")
        output_text.append(res)
    return output_text

# %% [markdown]
# ### Load saved model and predict using list of file path

# %%
def predict_by_saved_model(image_paths,model_path='model-100E-01.305L-18.03.23-02.29PM.h5'):
    # Loading the saved model
    loaded_model = tf.keras.models.load_model(model_path, custom_objects={'CTCLayer': CTCLayer})

    # Setting the prediction model
    prediction_model = tf.keras.models.Model(
        loaded_model.get_layer(name="image").input, loaded_model.get_layer(name="dense2").output
    )
    predictions = []
    for path in image_paths:
        # Load an image and preprocess it
        image = preprocess_image(path)

        # Make a prediction
        pred = prediction_model.predict(image[np.newaxis, ...])

        # Convert the predictions to text
        predicted_text = decode_batch_predictions(pred)
        predictions.append({path:predicted_text})
    
    return predictions

# %% [markdown]
# ### Predicting some with predict_by_saved_model function

# %%
image_paths = ['Datasets/IAM_Words/words/a03/a03-006/a03-006-00-00.png','Datasets/IAM_Words/words/a03/a03-006/a03-006-01-01.png','Datasets/IAM_Words/words/a03/a03-006/a03-006-02-00.png','Datasets/IAM_Words/words/a03/a03-006/a03-006-06-03.png',]

x = predict_by_saved_model(image_paths)
print(x)
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# [{'Datasets/IAM_Words/words/a03/a03-006/a03-006-00-00.png': ['Today']}, {'Datasets/IAM_Words/words/a03/a03-006/a03-006-01-01.png': ['arrived']}, {'Datasets/IAM_Words/words/a03/a03-006/a03-006-02-00.png': ['Foreign']}, {'Datasets/IAM_Words/words/a03/a03-006/a03-006-06-03.png': ['any']}]

# %% [markdown]
# ## Testing

# %%
t_true = []
t_pred = []
t_img = []

for batch in test_ds:
    batch_images = batch["image"]
    batch_label = batch["label"]

    preds = prediction_model.predict(batch_images)
    pred_texts = decode_batch_predictions(preds)
    for i in range(len(batch_images)):
        img = batch_images[i]
        img = tf.image.flip_left_right(img)
        img = tf.transpose(img, perm=[1, 0, 2])
        img = (img * 255.0).numpy().clip(0, 255).astype(np.uint8)
        img = img[:, :, 0]

        actual_text = get_label_in_text(batch_label[i])
        t_true.append(actual_text)
        t_pred.append(pred_texts[i])
        t_img.append(img)
# Out:
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 173ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 135ms/step

# %% [markdown]
# ### Accuracy Calculator

# %%
def calculate_accuracy_char(true,prediction):

    min_len = min( len(true), len(prediction) )

    for i in range( min_len ):
        for j in range( min( len( true[i] ), len( prediction[i] ) ) ):
            pass



def calculate_accuracy(true,prediction):
    count = 0
    min_len = min( len(true), len(prediction) )

    for i in range( min_len ):
        if true[i].lower() == prediction[i].lower():
            count+=1
    return count/min_len

# %%
acc = calculate_accuracy(t_true, t_pred)
print('Test Data Size : ',len(t_true))
print('Accuracy : ',acc*100,'%')
# Out:
# Test Data Size :  4823
# Accuracy :  75.67903794318889 %

# %% [markdown]
# ### Plotting The Predictions

# %%
def plot_prediction(true, prediction, images, row=6, column=4, figsize=(16, 9)):
    
    min_len = min( len(true), len(prediction), len(images) )
    _, ax = plt.subplots(row, column, figsize=figsize)
    
    for i in range(min_len):
        if(i<row*column):
            title = f"Real = {true[i]} || Pred = {prediction[i]}"
            ax[i //column, i % column].imshow(images[i], cmap="gray")
            ax[i //column, i % column].set_title(title)
            ax[i //column, i % column].axis("off")

# %%
plot_prediction(t_true[:24],t_pred[:24],t_img[:24])
